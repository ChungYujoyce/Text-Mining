# %%
# load data to pandas data frame
import pandas as pd
import numpy as np

doc_data = pd.read_csv('./movies_genre_60.csv', sep=",", header=0 )
movie_titles = doc_data['Title'].tolist()  # convert column Title of panda frame to list
movie_synopses = doc_data['Synopsis'].tolist()
movie_genre = doc_data['Genre'].tolist()
doc_data
# Out:
#                    Genre                                     Title  \
# 0   Action_Horror_Sci-Fi            1.1_Alien: Resurrection (1997)
# 1   Action_Horror_Sci-Fi                 1.2_Ghosts of Mars (2001)
# 2   Action_Horror_Sci-Fi      1.3_Resident Evil: Apocalypse (2004)
# 3   Action_Horror_Sci-Fi                 1.4_The Colony (I) (2013)
# 4   Action_Horror_Sci-Fi                      1.5_They Live (1988)
# 5   Action_Horror_Sci-Fi                        1.6_Jason X (2001)
# 6   Action_Horror_Sci-Fi                         1.7_Alien³ (1992)
# 7   Action_Horror_Sci-Fi                   1.8_DeepStar Six (1989)
# 8   Action_Horror_Sci-Fi                        1.9_The Meg (2018)
# 9   Action_Horror_Sci-Fi                 1.10_Resident Evil (2002)
# 10  Action_Horror_Sci-Fi            1.11_The Purge: Anarchy (2014)
# 11  Action_Horror_Sci-Fi                    1.12_Predator 2 (1990)
# 12  Action_Horror_Sci-Fi                       1.13_Upgrade (2018)
# 13  Action_Horror_Sci-Fi                    1.14_Underwater (2020)
# 14  Action_Horror_Sci-Fi               1.15_The First Purge (2018)
# 15  Action_Horror_Sci-Fi      1.16_The Purge: Election Year (2016)
# 16  Action_Horror_Sci-Fi                        1.17_Morgan (2016)
# 17  Action_Horror_Sci-Fi                         1.18_Blade (1998)
# 18  Action_Horror_Sci-Fi                    1.19_Hollow Man (2000)
# 19  Action_Horror_Sci-Fi  1.20_Aliens vs. Predator: Requiem (2007)
# 20        Comedy_Romance        2.1_No Strings Attached (I) (2011)
# 21        Comedy_Romance                   2.2_Pretty Woman (1990)
# 22        Comedy_Romance              2.3_Coming to America (1988)
# 23        Comedy_Romance                         2.4_Amélie (2001)
# 24        Comedy_Romance                2.5_Blame It on Rio (1984)
# 25        Comedy_Romance                     2.6_Annie Hall (1977)
# 26        Comedy_Romance                       2.7_Sex Tape (2014)
# 27        Comedy_Romance                2.8_Bridesmaids (I) (2011)
# 28        Comedy_Romance                         2.9_Arthur (1981)
# 29        Comedy_Romance                       2.10_Yes Man (2008)
# 30        Comedy_Romance                 2.11_Summer School (1987)
# 31        Comedy_Romance               2.12_Sixteen Candles (1984)
# 32        Comedy_Romance                    2.13_Knocked Up (2007)
# 33        Comedy_Romance      2.14_The Secret of My Success (1987)
# 34        Comedy_Romance                   2.15_Serendipity (2001)
# 35        Comedy_Romance              2.16_One Crazy Summer (1986)
# 36        Comedy_Romance                      2.17_Clueless (1995)
# 37        Comedy_Romance              2.18_Just Friends (I) (2005)
# 38        Comedy_Romance               2.19_Just Go with It (2011)
# 39        Comedy_Romance                          2.20_Dave (1993)
# 40             Drama_War                  3.1_The Duellists (1977)
# 41             Drama_War                 3.2_Paths of Glory (1957)
# 42             Drama_War                          3.3_Birdy (1984)
# 43             Drama_War            3.4_Beasts of No Nation (2015)
# 44             Drama_War                          3.5_Amigo (2010)
# 45             Drama_War            3.6_Saving Private Ryan (1998)
# 46             Drama_War                    3.7_Salon Kitty (1976)
# 47             Drama_War               3.8_Ivan's Childhood (1962)
# 48             Drama_War               3.9_The Green Berets (1968)
# 49             Drama_War                     3.10_Tigerland (2000)
# 50             Drama_War         3.11_The Boys in Company C (1978)
# 51             Drama_War               3.12_Before the Rain (1994)
# 52             Drama_War                    3.13_Hart's War (2002)
# 53             Drama_War              3.14_The Caine Mutiny (1954)
# 54             Drama_War                        3.15_Ararat (2002)
# 55             Drama_War                    3.16_Camp X-Ray (2014)
# 56             Drama_War                       3.17_Platoon (1986)
# 57             Drama_War            3.18_La Grande Illusion (1937)
# 58             Drama_War               3.19_Fugitive Pieces (2007)
# 59             Drama_War                      3.20_King Rat (1965)
#
#                                              Synopsis
# 0   200 years after the events of Alien 3, scienti...
# 1   200 years in the future, Mars has been coloniz...
# 2   30 days after the contamination of The Hive, t...
# 3   A terrified woman (Alex Paxton-Beesley) and a ...
# 4   George Nada (Roddy Piper) is a homeless labore...
# 5   In 2008, Jason Voorhees is captured by the U.S...
# 6   In the movie's opening credits, the Sulaco, th...
# 7   In the opening scene, Jim McBride (\r\nGreg Ev...
# 8   In the opening scene, Jonas Taylor (Jason Stat...
# 9   In the opening shot, a voice-over narrator exp...
# 10  In this indirect sequel to the first Purge fil...
# 11  Los Angeles, 1997. The temperature in the city...
# 12  Set sometime in the distant future, Grey Trace...
# 13  The film begins with images of the Mariana Tre...
# 14  The film opens with an insane junkie named Ske...
# 15  The film starts on Purge Night. A couple of ma...
# 16  The opening scene shows Dr. Kathy Grieff (Jenn...
# 17  The story opens in 1967 with a pregnant woman ...
# 18  This film is loosely based on H. G. Wells' "Th...
# 19  Two Predators load several live Alien facehugg...
# 20  15 years ago\r\nWe see two young kids, named E...
# 21  A very successful, wealthy lawyer, Edward Lewi...
# 22  Akeem Joffer (Eddie Murphy), the prince and he...
# 23  Amelie Poulain (Audrey Tautou) is the only chi...
# 24  American businessman Victor (Joseph Bologna) a...
# 25  Annie Hall is a film about a comedian, Alvy Si...
# 26  Annie Hargrove (\r\nCameron Diaz\r\n) is a 30-...
# 27  Annie Walker (\r\nKristen Wiig\r\n) is a singl...
# 28  Arthur Bach is a rich socialite from a financi...
# 29  As the studio credits roll, a pop tune starts ...
# 30  At Ocean Front High School in Los Angeles, it ...
# 31  Awkward high school sophomore Samantha "Sam" B...
# 32  Ben Stone (Seth Rogen) is a 23-year-old slacke...
# 33  Brantley Foster (Michael J. Fox) is a young co...
# 34  Can once in a lifetime happen twice?\r\nWhen J...
# 35  Cartoonist "Hoops" McCann (John Cusack) works ...
# 36  Cher Horowitz (Alicia Silverstone) is a wealth...
# 37  Chris Brander (Reynolds), an obese high school...
# 38  Danny Maccabee (Adam Sandler) is a successful ...
# 39  Dave Kovic (Kevin Kline) runs a temporary empl...
# 40  "The Duellists" is based on a story written by...
# 41  A voice-over narrator explains that Germany an...
# 42  A young man nicknamed Birdy (Matthew Modine) i...
# 43  Agu is a cheerful pre-teen boy playing barefoo...
# 44  AMIGO, the 17th feature film from Academy Awar...
# 45  An American flag back-lighted by the afternoon...
# 46  Around the beginning of II Word War, a nazi's ...
# 47  As the film opens, a 12-year-old boy is runnin...
# 48  At Fort Bragg, a U.S. Army training camp in No...
# 49  At Fort Polk, Louisiana, in September of 1971,...
# 50  August 1967\r\nFive young men arrive at boot c...
# 51  Before the Rain brought a vision of "Balkan co...
# 52  Belgium, December 16, 1944: First Lieutenant T...
# 53  Bogart is Lt. Commander Phillip Queeg assigned...
# 54  Brilliant Testimony to Legacy of Art and Histo...
# 55  Camp X-Ray centers on female soldier   (\r\nKr...
# 56  Chris Taylor (Charlie Sheen) is a young Americ...
# 57  During the First World War, two French aviator...
# 58  Fragments of past and present create a hauntin...
# 59  George Segal plays Corporal King, an American ...

# %% [markdown]
# #### Pre-Processing text

# %%
# Define function for Lemmatization, remove stopword and feature selection using POS, spacy package
import spacy
def spacy_preprocess(text,lemma= True, pos= True, pos_select = ["VERB", "NOUN", "ADJ","ADV","PART"]):
  # Initialize spacy 'en' model, keeping only tagger component needed for lemmatization
    nlp = spacy.load('en', disable=['parser', 'ner']) # disable parser, ner for faster loading
  # Parse the sentence using the loaded 'en' model object `nlp`
    doc = nlp(text)
    
    if pos== False:
        if lemma== True: text_preprocess= " ".join([token.lemma_.lower() for token in doc if not nlp.vocab[token.text].is_stop])
        if lemma== False:text_preprocess= " ".join([token.text.lower() for token in doc if not nlp.vocab[token.text].is_stop])
    else:
        if lemma== True : text_preprocess= " ".join([token.lemma_.lower() for token in doc if (token.pos_ in pos_select and not nlp.vocab[token.text].is_stop)])
        if lemma== False : text_preprocess= " ".join([token.text.lower() for token in doc if (token.pos_ in pos_select  and not nlp.vocab[token.text].is_stop)])
  # nlp.vocab[token.text].is_stop to remove stopwords
    return text_preprocess

# %%
# Pre-processing data with spacy
from tqdm import tqdm
movie_synopses_preprocess=[]
for movie in tqdm(movie_synopses):
    movie_preprocess = spacy_preprocess(movie,pos_select = ["VERB", "NOUN", "ADJ"])
    movie_synopses_preprocess+= [movie_preprocess]
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 60/60 [00:42<00:00,  1.40it/s]

# %% [markdown]
# Build feature matrix (tf-idf)

# %%
#change data input (movie_synopses or movie_synopses_preprocess) here
data_input1 = movie_synopses
data_input2 = movie_synopses_preprocess 

from sklearn.feature_extraction.text import TfidfVectorizer
vectorizer = TfidfVectorizer(min_df=0.1, max_df=0.8, max_features= None)
feature_matrix1 = vectorizer.fit_transform(data_input1).astype(float)
feature_names1 = vectorizer.get_feature_names() # get feature names
print("number of feature:", len(feature_names1))

feature_matrix2 = vectorizer.fit_transform(data_input2).astype(float)
feature_names2 = vectorizer.get_feature_names() # get feature names
print("number of feature:", len(feature_names2))
# Out:
# number of feature: 1131
# number of feature: 789

# %% [markdown]
# #### Kmean Clustering
#
# (a) Test 1: Does using text preprocessing give a better result?
# Run Kmean clustering in 2 cases and compare the purify

# %%
from sklearn.cluster import KMeans
#function for Kmean clustering
def k_means(feature_matrix, num_clusters):
    km = KMeans(n_clusters=num_clusters, n_init=500, random_state = 1,
                max_iter=10000)
    km.fit(feature_matrix)
    clusters = km.labels_
    return km, clusters

def get_cluster_data(clustering_obj, doc_data, 
                     feature_names, num_clusters,
                     topn_features=10):

    cluster_details = {}  
    # get cluster centroids
    ordered_centroids = clustering_obj.cluster_centers_.argsort()[:, ::-1]
    # get key features for each cluster
    # get docs belonging to each cluster
    for cluster_num in range(num_clusters):
        cluster_details[cluster_num] = {}
        cluster_details[cluster_num]['cluster_num'] = cluster_num
        key_features = [feature_names[index] 
                        for index 
                        in ordered_centroids[cluster_num, :topn_features]]
        cluster_details[cluster_num]['key_features'] = key_features
        
        docs = doc_data[doc_data['Cluster'] == cluster_num]['Title'].values.tolist()
        cluster_details[cluster_num]['docs'] = docs
    
    return cluster_details

def print_clusters(cluster_data):
    # print cluster details
    for cluster_num, cluster_details in cluster_data.items():
        print ('Cluster {} details:'.format(cluster_num))
        print ('-'*20)
        print ('Key features:', cluster_details['key_features'])
        print ('docs in this cluster:')
        print (', '.join(cluster_details['docs']))
        print ('='*40)

# %%
def count_purity(cluster_data):
    max_group = 0
    for cluster_num, cluster_details in cluster_data.items():
        group1, group2, group3 = 0, 0, 0
        
        for item in cluster_details['docs']:
            if item.split('.')[0] == '1':
                group1 += 1
            elif item.split('.')[0]  == '2':
                group2 += 1
            else:
                group3 += 1
        print(group1, group2, group3)
        max_group += max(group1, group2, group3)
        #print(max_group)
    return max_group / 60

# %% [markdown]
# without preprocess

# %%
# assume that we want to clustering withy k =3
num_clusters = 3
km_obj1, km_clusters1 = k_means(feature_matrix=feature_matrix1,
                           num_clusters=num_clusters)

doc_data['Cluster'] = km_clusters1

km_cluster_data1 =  get_cluster_data(clustering_obj=km_obj1,
                                 doc_data = doc_data,
                                 feature_names=feature_names1,
                                 num_clusters=num_clusters,
                                 topn_features=10)

print_clusters(km_cluster_data1) 

purity = count_purity(km_cluster_data1)
print("Purity: ", purity)
# Out:
# Cluster 0 details:
# --------------------
# Key features: ['from', 'house', 'school', 'home', 'wedding', 'back', 'father', 'love', 'while', 'time']
# docs in this cluster:
# 1.16_The Purge: Election Year (2016), 2.1_No Strings Attached (I) (2011), 2.2_Pretty Woman (1990), 2.3_Coming to America (1988), 2.4_Amélie (2001), 2.5_Blame It on Rio (1984), 2.6_Annie Hall (1977), 2.7_Sex Tape (2014), 2.8_Bridesmaids (I) (2011), 2.9_Arthur (1981), 2.10_Yes Man (2008), 2.11_Summer School (1987), 2.12_Sixteen Candles (1984), 2.13_Knocked Up (2007), 2.14_The Secret of My Success (1987), 2.15_Serendipity (2001), 2.16_One Crazy Summer (1986), 2.17_Clueless (1995), 2.18_Just Friends (I) (2005), 2.19_Just Go with It (2011), 2.20_Dave (1993), 3.3_Birdy (1984), 3.7_Salon Kitty (1976), 3.8_Ivan's Childhood (1962), 3.12_Before the Rain (1994), 3.19_Fugitive Pieces (2007)
# ========================================
# Cluster 1 details:
# --------------------
# Key features: ['camp', 'from', 'war', 'men', 'german', 'soldier', 'sergeant', 'soldiers', 'captain', 'village']
# docs in this cluster:
# 3.1_The Duellists (1977), 3.2_Paths of Glory (1957), 3.4_Beasts of No Nation (2015), 3.5_Amigo (2010), 3.6_Saving Private Ryan (1998), 3.9_The Green Berets (1968), 3.10_Tigerland (2000), 3.11_The Boys in Company C (1978), 3.13_Hart's War (2002), 3.14_The Caine Mutiny (1954), 3.16_Camp X-Ray (2014), 3.17_Platoon (1986), 3.18_La Grande Illusion (1937), 3.20_King Rat (1965)
# ========================================
# Cluster 2 details:
# --------------------
# Key features: ['from', 'then', 'one', 'into', 'crew', 'dr', 'people', 'matt', 'back', 'blade']
# docs in this cluster:
# 1.1_Alien: Resurrection (1997), 1.2_Ghosts of Mars (2001), 1.3_Resident Evil: Apocalypse (2004), 1.4_The Colony (I) (2013), 1.5_They Live (1988), 1.6_Jason X (2001), 1.7_Alien³ (1992), 1.8_DeepStar Six (1989), 1.9_The Meg (2018), 1.10_Resident Evil (2002), 1.11_The Purge: Anarchy (2014), 1.12_Predator 2 (1990), 1.13_Upgrade (2018), 1.14_Underwater (2020), 1.15_The First Purge (2018), 1.17_Morgan (2016), 1.18_Blade (1998), 1.19_Hollow Man (2000), 1.20_Aliens vs. Predator: Requiem (2007), 3.15_Ararat (2002)
# ========================================
# 1 20 5
# 0 0 14
# 19 0 1
# Purity:  0.8833333333333333

# %% [markdown]
# with preprocess

# %%
km_obj2, km_clusters2 = k_means(feature_matrix=feature_matrix2,
                           num_clusters=num_clusters)

doc_data['Cluster'] = km_clusters2

km_cluster_data2 =  get_cluster_data(clustering_obj=km_obj2,
                                 doc_data = doc_data,
                                 feature_names=feature_names2,
                                 num_clusters=num_clusters,
                                 topn_features=10)

print_clusters(km_cluster_data2)
# Out:
# Cluster 0 details:
# --------------------
# Key features: ['kill', 'shoot', 'try', 'attack', 'crew', 'ship', 'creature', 'go', 'tell', 'escape']
# docs in this cluster:
# 1.1_Alien: Resurrection (1997), 1.2_Ghosts of Mars (2001), 1.3_Resident Evil: Apocalypse (2004), 1.4_The Colony (I) (2013), 1.5_They Live (1988), 1.6_Jason X (2001), 1.7_Alien³ (1992), 1.8_DeepStar Six (1989), 1.9_The Meg (2018), 1.10_Resident Evil (2002), 1.11_The Purge: Anarchy (2014), 1.12_Predator 2 (1990), 1.13_Upgrade (2018), 1.14_Underwater (2020), 1.15_The First Purge (2018), 1.16_The Purge: Election Year (2016), 1.17_Morgan (2016), 1.18_Blade (1998), 1.19_Hollow Man (2000), 1.20_Aliens vs. Predator: Requiem (2007), 3.14_The Caine Mutiny (1954)
# ========================================
# Cluster 1 details:
# --------------------
# Key features: ['tell', 'love', 'school', 'time', 'relationship', 'friend', 'wedding', 'father', 'film', 'take']
# docs in this cluster:
# 2.1_No Strings Attached (I) (2011), 2.2_Pretty Woman (1990), 2.3_Coming to America (1988), 2.4_Amélie (2001), 2.5_Blame It on Rio (1984), 2.6_Annie Hall (1977), 2.7_Sex Tape (2014), 2.8_Bridesmaids (I) (2011), 2.9_Arthur (1981), 2.10_Yes Man (2008), 2.11_Summer School (1987), 2.12_Sixteen Candles (1984), 2.13_Knocked Up (2007), 2.14_The Secret of My Success (1987), 2.15_Serendipity (2001), 2.16_One Crazy Summer (1986), 2.17_Clueless (1995), 2.18_Just Friends (I) (2005), 2.19_Just Go with It (2011), 2.20_Dave (1993), 3.3_Birdy (1984), 3.7_Salon Kitty (1976), 3.8_Ivan's Childhood (1962), 3.12_Before the Rain (1994), 3.15_Ararat (2002), 3.19_Fugitive Pieces (2007)
# ========================================
# Cluster 2 details:
# --------------------
# Key features: ['soldier', 'camp', 'man', 'war', 'german', 'order', 'officer', 'kill', 'enemy', 'village']
# docs in this cluster:
# 3.1_The Duellists (1977), 3.2_Paths of Glory (1957), 3.4_Beasts of No Nation (2015), 3.5_Amigo (2010), 3.6_Saving Private Ryan (1998), 3.9_The Green Berets (1968), 3.10_Tigerland (2000), 3.11_The Boys in Company C (1978), 3.13_Hart's War (2002), 3.16_Camp X-Ray (2014), 3.17_Platoon (1986), 3.18_La Grande Illusion (1937), 3.20_King Rat (1965)
# ========================================

# %%
purity2 = count_purity(km_cluster_data2)
print("Purity: ", purity2)
# Out:
# 20 0 1
# 0 20 6
# 0 0 13
# Purity:  0.8833333333333333

# %% [markdown]
# We can see that the purity is the same with or without text preprocess, but I think with text preprocess is better so I gonna use the result.

# %% [markdown]
# (b) Test 2: if we limit the max_feature, does it affect the model performance?

# %%
def compare_max_feature(max_feature):
    vectorizer = TfidfVectorizer(min_df=0.1, max_df=0.8, max_features= max_feature)
    feature_matrix = vectorizer.fit_transform(data_input2).astype(float)
    feature_names = vectorizer.get_feature_names() # get feature names
    print("number of feature:", len(feature_names))
    km_obj, km_clusters = k_means(feature_matrix=feature_matrix,
                               num_clusters=num_clusters)

    doc_data['Cluster'] = km_clusters

    km_cluster_data =  get_cluster_data(clustering_obj=km_obj,
                                     doc_data = doc_data,
                                     feature_names=feature_names,
                                     num_clusters=num_clusters,
                                     topn_features=10)

    #rint_clusters(km_cluster_data)
    purity = count_purity(km_cluster_data)
    #print("Purity: ", purity)
    return purity

# %%
purity = []
for i in range(100,800,100):
    purity.append(compare_max_feature(i))

import matplotlib.pyplot as plt 

max_feature = [100, 200, 300, 400, 500, 600, 700]
plt.plot(max_feature, purity) 
plt.xlabel('max_feature') 
plt.ylabel('purity') 
plt.show()
# Out:
# number of feature: 100
# 1 0 18
# 0 20 2
# 19 0 0
# number of feature: 200
# 20 0 0
# 0 20 4
# 0 0 16
# number of feature: 300
# 0 0 14
# 0 20 5
# 20 0 1
# number of feature: 400
# 0 0 14
# 20 0 0
# 0 20 6
# number of feature: 500
# 0 20 6
# 19 0 1
# 1 0 13
# number of feature: 600
# 0 20 6
# 19 0 1
# 1 0 13
# number of feature: 700
# 20 0 1
# 0 20 6
# 0 0 13

# %% [markdown]
# Con

# %% [markdown]
# #### Ward Hierarchical clustering

# %% [markdown]
# (c1) Run Ward Hierarchical clustering in 2 cases (with and without preprocessing).
# Looking at the dendrogram graph, according to you, which case give better result.

# %%
# Function to form and plot hierarchical clustering

def ward_hierarchical_clustering(feature_matrix):
    
    cosine_distance = 1 - cosine_similarity(feature_matrix)
    linkage_matrix = ward(cosine_distance)
    return linkage_matrix

def plot_hierarchical_clusters(linkage_matrix, doc_data, figure_size=(8,12)):
    # set size
    fig, ax = plt.subplots(figsize=figure_size,dpi=150) 
    doc_titles = doc_data['Title'].values.tolist()
    # plot dendrogram
    ax = dendrogram(linkage_matrix, orientation="left", labels=doc_titles)
    plt.tick_params(axis= 'x',   
                    which='both',  
                    bottom=False,
                    top=False,
                    labelbottom= False)
    plt.tight_layout()
    plt.savefig('./hierachical_full.png', dpi=600)

import matplotlib.pyplot as plt
from sklearn.manifold import MDS
from sklearn.metrics.pairwise import cosine_similarity
import random
from matplotlib.font_manager import FontProperties
from scipy.cluster.hierarchy import ward, dendrogram

# build ward's linkage matrix    
linkage_matrix = ward_hierarchical_clustering(feature_matrix)
plot_hierarchical_clusters(linkage_matrix=linkage_matrix, doc_data=doc_data, figure_size=(6,8))
# you can find the file "hierachical_full.png"

# %% [markdown]
# (c2) Compare with Kmean: what are the pros and cons in this case?
# (you need to look at result and give your opinion, you will not get points for theoretical comparisons only)

# %% [markdown]
# #### SOM Clustering

# %% [markdown]
# Looking at the SOM clustering, can you separate or distinguish the area of 3 group of movies? in your opinion, what is the pros and cons of SOM? (*) the SOM clustering result sometime make confusing, fell free to give your opinion.  (*) you can change some parameter such as number of neuron output, … Just need to try several cases. Do not try too many cases, it will take a lot of your time.

# %%
# !pip install minisom
# Out:
# Requirement already satisfied: minisom in c:\users\user\anaconda3\lib\site-packages (2.2.5)

# %%
#Step 1 tranining the Neural network 
D = feature_matrix.todense().tolist()
from minisom import MiniSom
max_features=len(feature_names)
xmap_dim =8
ymap_dim =8


som = MiniSom(x=xmap_dim, y= ymap_dim, input_len= max_features, random_seed=1)

import time
start = time.time()

#start training
som.pca_weights_init(D)
som.train_batch(data=D, num_iteration= max_features*200)
#end tranining
end = time.time()
print(end - start,'seconds')
# Out:
# C:\Users\USER\Anaconda3\lib\site-packages\minisom.py:366: ComplexWarning: Casting complex values to real discards the imaginary part
#   self._weights[i, j] = c1*pc[pc_order[0]] + c2*pc[pc_order[1]]
# 115.11253094673157 seconds

# %%
# show cluster in movies titles
titles=movie_titles

plt.figure(figsize=(20, 20))
for i, (t, vec) in enumerate(zip(titles, D)):
    winnin_position = som.winner(vec)
    plt.text(winnin_position[0], 
             winnin_position[1]+np.random.rand()*0.9, 
             t[0:20], color='black')
    
plt.xticks(range(xmap_dim))
plt.yticks(range(ymap_dim))
plt.grid()
plt.xlim([0, xmap_dim])
plt.ylim([0, ymap_dim])
plt.plot()
plt.savefig('./som_titles.png', dpi=300)

# %%
#Movies name, key feature and genre of every cluster
top_keywords =10
weights = som.get_weights()
for i in range(xmap_dim):
    for j in range(ymap_dim):
        keywords_idx = np.argsort(weights[i,j,:])[-top_keywords:]
        keywords = ' '.join([feature_names[k] for k in keywords_idx])
        print('\n')
        print('Cell', i,'-',j, '-','keyword:', keywords)
        movies_t =[]     
        for k, (t, g, vec) in enumerate(zip(movie_titles, movie_genre, D)):
            winnin_position = som.winner(vec)
            if winnin_position[0]==i and winnin_position[1]==j: 
                movies_t+=[t]
          
        print('Titles:', movies_t)
# Out:
# Cell 0 - 0 - keyword: attack war camp from general soldier men soldiers sergeant enemy
# Titles: ['3.2_Paths of Glory (1957)', '3.9_The Green Berets (1968)', '3.17_Platoon (1986)']
#
#
# Cell 0 - 1 - keyword: unit enemy soldier camp war soldiers from men squad german
# Titles: ['3.6_Saving Private Ryan (1998)']
#
#
# Cell 0 - 2 - keyword: from tunnel escape guards fellow french prisoners war camp german
# Titles: ["3.13_Hart's War (2002)", '3.18_La Grande Illusion (1937)']
#
#
# Cell 0 - 3 - keyword: because war lieutenant gain officers fellow clear prisoners american camp
# Titles: ['3.20_King Rat (1965)']
#
#
# Cell 0 - 4 - keyword: real one acting word create serious movie film or order
# Titles: ['3.7_Salon Kitty (1976)']
#
#
# Cell 0 - 5 - keyword: mark identity form real people story level different movie history
# Titles: ['3.15_Ararat (2002)']
#
#
# Cell 0 - 6 - keyword: powerful friendship officer civilians considers chris hunt from history village
# Titles: ['3.5_Amigo (2010)']
#
#
# Cell 0 - 7 - keyword: under called crew himself command former whose officer ship blade
# Titles: ['1.18_Blade (1998)', '3.14_The Caine Mutiny (1954)']
#
#
# Cell 1 - 0 - keyword: village colonel team from soldiers men general enemy attack company
# Titles: ['3.11_The Boys in Company C (1978)']
#
#
# Cell 1 - 1 - keyword: squad enemy troops camp soldiers war orders from men german
# Titles: []
#
#
# Cell 1 - 2 - keyword: there then shot prisoners man orders german war troops camp
# Titles: ['3.4_Beasts of No Nation (2015)']
#
#
# Cell 1 - 3 - keyword: man we prison or prisoners headquarters war george film camp
# Titles: []
#
#
# Cell 1 - 4 - keyword: before red all prison were its or headquarters we film
# Titles: ['1.2_Ghosts of Mars (2001)', '3.12_Before the Rain (1994)']
#
#
# Cell 1 - 5 - keyword: all kind story movie different headquarters we film history chris
# Titles: []
#
#
# Cell 1 - 6 - keyword: officer powerful civilians considers friendship hunt from history chris village
# Titles: []
#
#
# Cell 1 - 7 - keyword: himself while two re find number officer ship jason blade
# Titles: []
#
#
# Cell 2 - 0 - keyword: ends face two wounded soldiers captain from this general lieutenant
# Titles: ['3.1_The Duellists (1977)']
#
#
# Cell 2 - 1 - keyword: will mother through scene old informs this across boy river
# Titles: ["3.8_Ivan's Childhood (1962)"]
#
#
# Cell 2 - 2 - keyword: cell denies female finds camp base duty book from suicide
# Titles: ['3.16_Camp X-Ray (2014)']
#
#
# Cell 2 - 3 - keyword: school raymond dog into drive team from money friends george
# Titles: ['2.16_One Crazy Summer (1986)']
#
#
# Cell 2 - 4 - keyword: we old present headquarters school family george past film chris
# Titles: []
#
#
# Cell 2 - 5 - keyword: james thinking kiss party love successful high feelings school chris
# Titles: ['2.18_Just Friends (I) (2005)']
#
#
# Cell 2 - 6 - keyword: thinking starting each find two re school number chris jason
# Titles: []
#
#
# Cell 2 - 7 - keyword: will other phone each starting two find re number jason
# Titles: ['1.6_Jason X (2001)', '2.15_Serendipity (2001)']
#
#
# Cell 3 - 0 - keyword: wants soon helps loses bus training especially sergeant soldier private
# Titles: ['3.10_Tigerland (2000)']
#
#
# Cell 3 - 1 - keyword: make one realizes soldier real river town into private from
# Titles: []
#
#
# Cell 3 - 2 - keyword: ship however city center realizes station destroy from helicopter town
# Titles: ['1.20_Aliens vs. Predator: Requiem (2007)']
#
#
# Cell 3 - 3 - keyword: create old from friends town present family into past george
# Titles: []
#
#
# Cell 3 - 4 - keyword: members little moving into reveal words create family present past
# Titles: ['3.19_Fugitive Pieces (2007)']
#
#
# Cell 3 - 5 - keyword: kids pass whom class test chris student day job school
# Titles: ['2.11_Summer School (1987)']
#
#
# Cell 3 - 6 - keyword: father party test high student home day mr job school
# Titles: []
#
#
# Cell 3 - 7 - keyword: life each york love number find johnson father marry jason
# Titles: []
#
#
# Cell 4 - 0 - keyword: find military from into mask then team frank dr matt
# Titles: ['1.19_Hollow Man (2000)']
#
#
# Cell 4 - 1 - keyword: ill staff realizes house from secret frank first office real
# Titles: ['2.20_Dave (1993)']
#
#
# Cell 4 - 2 - keyword: local human into office helicopter one from church police frank
# Titles: ['1.5_They Live (1988)']
#
#
# Cell 4 - 3 - keyword: get into church have off one night house store frank
# Titles: []
#
#
# Cell 4 - 4 - keyword: family get begin off apartment have night baby store house
# Titles: ['1.16_The Purge: Election Year (2016)', '2.13_Knocked Up (2007)']
#
#
# Cell 4 - 5 - keyword: store begin night very wedding job day home house school
# Titles: []
#
#
# Cell 4 - 6 - keyword: life interest high party love hall home father mr school
# Titles: ['2.17_Clueless (1995)']
#
#
# Cell 4 - 7 - keyword: york america daughter family life wedding love johnson father marry
# Titles: ['2.3_Coming to America (1988)', '2.9_Arthur (1981)']
#
#
# Cell 5 - 0 - keyword: team escape then was into soon helicopter matt city dr
# Titles: ['1.3_Resident Evil: Apocalypse (2004)']
#
#
# Cell 5 - 1 - keyword: team room real into tells also dr city office from
# Titles: []
#
#
# Cell 5 - 2 - keyword: also himself building able meeting office from company tells room
# Titles: ['1.12_Predator 2 (1990)', '2.14_The Secret of My Success (1987)']
#
#
# Cell 5 - 3 - keyword: night where one back office company building from tells room
# Titles: []
#
#
# Cell 5 - 4 - keyword: back before house church goes way people where streets get
# Titles: ['1.15_The First Purge (2018)']
#
#
# Cell 5 - 5 - keyword: friends drive which church very day home school house wedding
# Titles: ['2.12_Sixteen Candles (1984)']
#
#
# Cell 5 - 6 - keyword: together apartment speaking school box wedding life home from father
# Titles: ['2.4_Amélie (2001)']
#
#
# Cell 5 - 7 - keyword: daughter johnson apartment wedding love from home life marry father
# Titles: []
#
#
# Cell 6 - 0 - keyword: this everyone off tries wall back escape from dr crew
# Titles: ['1.9_The Meg (2018)']
#
#
# Cell 6 - 1 - keyword: dr into company off some people one back crew from
# Titles: []
#
#
# Cell 6 - 2 - keyword: from outside have room some which meeting tells leader people
# Titles: ['1.4_The Colony (I) (2013)']
#
#
# Cell 6 - 3 - keyword: man gets into tells see back says room from then
# Titles: []
#
#
# Cell 6 - 4 - keyword: drive back couple sex home car then video from get
# Titles: ['1.11_The Purge: Anarchy (2014)', '2.7_Sex Tape (2014)']
#
#
# Cell 6 - 5 - keyword: then back from get sex car house home relationship wedding
# Titles: []
#
#
# Cell 6 - 6 - keyword: encourages apartment party tells trip becomes house relationship home wedding
# Titles: ['2.8_Bridesmaids (I) (2011)']
#
#
# Cell 6 - 7 - keyword: rather work back deal goes money day gets clothes dinner
# Titles: ['2.2_Pretty Woman (1990)']
#
#
# Cell 7 - 0 - keyword: reach water surface one able call station escape from crew
# Titles: ['1.1_Alien: Resurrection (1997)', '1.8_DeepStar Six (1989)', '1.14_Underwater (2020)']
#
#
# Cell 7 - 1 - keyword: there prison can will into one crew company from prisoners
# Titles: ['1.7_Alien³ (1992)']
#
#
# Cell 7 - 2 - keyword: door then which from into floor back off tells room
# Titles: ['3.3_Birdy (1984)']
#
#
# Cell 7 - 3 - keyword: was asks where peter see gets into says room then
# Titles: ['1.10_Resident Evil (2002)', '1.17_Morgan (2016)', '2.10_Yes Man (2008)']
#
#
# Cell 7 - 4 - keyword: gun through takes shoots where home from was car then
# Titles: ['1.13_Upgrade (2018)']
#
#
# Cell 7 - 5 - keyword: love need we success gets happy york hall again relationship
# Titles: ['2.6_Annie Hall (1977)']
#
#
# Cell 7 - 6 - keyword: again other feelings each love we telling tells wedding relationship
# Titles: ['2.1_No Strings Attached (I) (2011)']
#
#
# Cell 7 - 7 - keyword: morning asks spend husband wedding michael affair dinner married kids
# Titles: ['2.5_Blame It on Rio (1984)', '2.19_Just Go with It (2011)']
