# %%
# !pip install minisom
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

doc_data = pd.read_csv('./movie_data_70.csv')
movie_titles = doc_data['Title'].tolist()  # convert column Title of panda frame to list
movie_genre = doc_data['Genre'].tolist()
movie_synopses = doc_data['Synopsis'].tolist()
doc_data
# Out:
# Requirement already satisfied: minisom in c:\users\user\anaconda3\lib\site-packages (2.2.5)
#                           Genre  \
# 0   Adventure, Biography, Drama
# 1   Adventure, Biography, Drama
# 2     Adventure, Drama, Fantasy
# 3     Adventure, Drama, History
# 4     Adventure, Drama, Romance
# 5    Adventure, Drama, Thriller
# 6         Adventure, Drama, War
# 7     Adventure, Drama, Western
# 8     Adventure, Drama, Western
# 9     Adventure, Drama, Western
# 10      Biography, Crime, Drama
# 11      Biography, Crime, Drama
# 12     Biography, Drama, Family
# 13    Biography, Drama, History
# 14    Biography, Drama, History
# 15    Biography, Drama, History
# 16   Biography, Drama, History
# 17   Biography, Drama, History
# 18      Biography, Drama, Music
# 19    Biography, Drama, Musical
# 20   Biography, Drama, Romance
# 21      Biography, Drama, Sport
# 22        Biography, Drama, War
# 23                       Comedy
# 24                Comedy, Drama
# 25                Comedy, Drama
# 26                Comedy, Drama
# 27         Comedy, Drama, Music
# 28       Comedy, Drama, Romance
# 29       Comedy, Drama, Romance
# ..                          ...
# 40                 Crime, Drama
# 41                 Crime, Drama
# 42        Crime, Drama, Fantasy
# 43      Crime, Drama, Film-Noir
# 44        Crime, Drama, Musical
# 45       Crime, Drama, Thriller
# 46       Crime, Drama, Thriller
# 47       Crime, Drama, Thriller
# 48                        Drama
# 49                        Drama
# 50                        Drama
# 51                        Drama
# 52                        Drama
# 53                        Drama
# 54                        Drama
# 55                       Drama
# 56               Drama, Romance
# 57               Drama, Romance
# 58               Drama, Romance
# 59               Drama, Romance
# 60               Drama, Romance
# 61          Drama, Romance, War
# 62          Drama, Romance, War
# 63          Drama, Romance, War
# 64          Drama, Romance, War
# 65                   Drama, War
# 66                   Drama, War
# 67                   Drama, War
# 68                   Drama, War
# 69                   Drama, War
#
#                                                 Title  \
# 0                                  Lawrence of Arabia
# 1                                Mutiny on the Bounty
# 2       The Lord of the Rings: The Return of the King
# 3                                             Ben-Hur
# 4                                   The African Queen
# 5                                                Jaws
# 6                        The Bridge on the River Kwai
# 7                    The Treasure of the Sierra Madre
# 8                                  Dances with Wolves
# 9                                          Stagecoach
# 10                 Butch Cassidy and the Sundance Kid
# 11                                         Goodfellas
# 12                                 The Sound of Music
# 13                                   Schindler's List
# 14                                            Amadeus
# 15                                         Braveheart
# 16                                             Gandhi
# 17                                  The King's Speech
# 18                                        The Pianist
# 19                                Yankee Doodle Dandy
# 20                                      Out of Africa
# 21                                        Raging Bull
# 22                                             Patton
# 23  Dr. Strangelove or: How I Learned to Stop Worr...
# 24                       Mr. Smith Goes to Washington
# 25                                Terms of Endearment
# 26                                  American Graffiti
# 27                                          Nashville
# 28                                      The Apartment
# 29                                        City Lights
# ..                                                ...
# 40                                       Pulp Fiction
# 41                                        Taxi Driver
# 42                                     The Green Mile
# 43                                   Double Indemnity
# 44                                    West Side Story
# 45                                  On the Waterfront
# 46                           The Silence of the Lambs
# 47                                              Fargo
# 48                           The Shawshank Redemption
# 49                    One Flew Over the Cuckoo's Nest
# 50                                       12 Angry Men
# 51                           A Streetcar Named Desire
# 52                                    Midnight Cowboy
# 53                                           Rain Man
# 54                              Rebel Without a Cause
# 55                                            Network
# 56                                            Titanic
# 57                                       Forrest Gump
    nlp = spacy.load('en', disable=['parser', 'ner'])
    # Parse the sentence using the loaded 'en' model object `nlp`
    doc = nlp(text)
    # Extract the lemma for each token and join
    text_lem= " ".join([token.lemma_ for token in doc])
    return text_lem

import nltk
nltk.download('punkt')
nltk.download('stopwords')
def normalize(text):
    tokens = nltk.word_tokenize(text)
    from nltk.corpus import stopwords
    stopwords_en = stopwords.words('english')
    # add more user stopwords
    stopwords_user  = ['mr', 'mrs', 'come', 'go', 'get',
                     'tell', 'listen', 'one', 'two', 'three',
                      'four', 'five', 'six', 'seven', 'eight',
                      'nine', 'zero', 'join', 'find', 'make',
                      'say', 'ask', 'tell', 'see', 'try', 'back',
                      'also','york','michael','never','soon','john','would','could','attempt',
                        'reach', ]

    stopwords = set(stopwords_en + stopwords_user)


    filtered_tokens = [w.lower() for w in tokens if w.lower() not in stopwords and w.isalnum()] # remove stopwords and punctuation from tokens
    text = " ".join(filtered_tokens)
    return (text)
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\USER\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\USER\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
#this take around 45 seconds
# lemmatizer and normalize for every movies synopses
from tqdm import tqdm 
norm_movie_synopses=[]
for i in tqdm(range(len(movie_synopses))):
    synopses_lem = spacy_Lemmatizer(movie_synopses[i])
    norm_movie_synopses+= [normalize(synopses_lem)]
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 70/70 [00:50<00:00,  1.39it/s]

# %%
max_features= 300
from sklearn.feature_extraction.text import TfidfVectorizer
vectorizer = TfidfVectorizer(min_df=0.15, max_df=0.6, max_features= max_features)
feature_matrix = vectorizer.fit_transform(norm_movie_synopses).astype(float)
feature_names = vectorizer.get_feature_names() # get feature names
print("number of feature:", len(feature_names))
# Out:
# number of feature: 300

# %%
#display feature matrix
pd.DataFrame(feature_matrix.toarray(), columns=feature_names)

# %%
#Step 1 tranining the Neural network 
# som_2 with 2x3 output - take about 1-2 minutes
D = feature_matrix.todense().tolist()
from minisom import MiniSom
som_6 = MiniSom(x=2, y= 3, input_len= max_features, random_seed=100)
import time
start = time.time()

#start training
som_6.pca_weights_init(D)
som_6.train_batch(data=D, num_iteration= max_features*2000)
#end tranining
end = time.time()
print(end - start,'seconds')

# %%
#Movies name, key feature and genre of every cluster
top_keywords =10
xmap_dim=2
ymap_dim=3
weights = som_6.get_weights()
for i in range(xmap_dim):
    
    for j in range(ymap_dim):
        keywords_idx = np.argsort(weights[i,j,:])[-top_keywords:]
        keywords = ' '.join([feature_names[k] for k in keywords_idx])
        print('\n')
        print('Cell', i,'-',j, '-','keyword:', keywords)
        movies_t =[]
        movies_g =[]
        for k, (t, g, vec) in enumerate(zip(movie_titles, movie_genre, D)):
            winnin_position = som_6.winner(vec)
            if winnin_position[0]==i and winnin_position[1]==j: 
                movies_t+=[t]
                movies_g+=[g]
        print('Titles:', movies_t)
        print('Genre:', movies_g)

# %%
# Out:
# 51.00727677345276 seconds

# %%
D = feature_matrix.todense().tolist()
from minisom import MiniSom
som_100 = MiniSom(10, 10, max_features, random_seed=100)

import time
start = time.time()

#start training
som_100.pca_weights_init(D)
som_100.train_batch(D, num_iteration=max_features*2000)
#end tranining
end = time.time()
print(end - start,'seconds')

# %%
# show cluster in movies titles
titles=movie_titles
xmap_dim=10
ymap_dim=10

plt.figure(figsize=(20, 20))
for i, (t, vec) in enumerate(zip(titles, D)):
    winnin_position = som_100.winner(vec)
    plt.text(winnin_position[0], 
             winnin_position[1]+np.random.rand()*0.9, 
             t[0:20], color='black')
    
plt.xticks(range(xmap_dim))
plt.yticks(range(ymap_dim))
plt.grid()
plt.xlim([0, xmap_dim])
plt.ylim([0, ymap_dim])
plt.plot()
plt.savefig('./som_100_titles.png', dpi=300)
